# %%
import torch
print(torch.__version__, torch.version.cuda, torch.cuda.is_available())
# Out:
# 2.8.0+cu128 12.8 True

# %%
# Johnson Main Module (Van Gogh)
import os, math, time, random
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchvision import models, transforms
from PIL import Image
import numpy as np

# --------------------- Config ---------------------
CONTENT_IMAGE = "content test2.jpg"     # (your content path)
STYLE_IMAGE   = "Van_Gogh_-_Starry_Night.jpg"   # (your style path)
OUTPUT_IMAGE  = "johnson_stylized2.jpg"
MODEL_PATH    = "transform_net.pth"

# Minimal "dataset" defaults to the single content image; point this to a folder for better training
CONTENT_DIR   = "content"       # folder of training content images (e.g., "./coco_subset"); "." uses the single content image
IMAGE_SIZE    = 512       # train/infer resolution (256/512/768). Higher => better quality, slower training
BATCH_SIZE    = 4
NUM_EPOCHS    = 2         # increase (e.g., 2–4) if you have a folder of content images
LEARNING_RATE = 1e-3
SEED          = 42
DEVICE        = "cuda" if torch.cuda.is_available() else "cpu"

# Perceptual loss weights (Johnson et al. typical ranges)
CONTENT_WEIGHT = 0.5
STYLE_WEIGHT   = 1e4      # try 5e3–1e4; if style is weak, raise this
TV_WEIGHT      = 1e-6

# VGG style/content layers (Johnson et al.: content=relu2_2; style=relu1_2, relu2_2, relu3_3, relu4_3)
LAYER_IDX = {
    "relu1_2": 3,
    "relu2_2": 8,
    "relu3_3": 15,
    "relu4_3": 22
}
STYLE_LAYERS   = ["relu1_2","relu2_2","relu3_3","relu4_3"]
CONTENT_LAYER  = "relu2_2"

random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# --------------------- Utils ---------------------
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

def load_image(path, size=None):
    img = Image.open(path).convert("RGB")
    if size is not None:
        img = img.resize((size, size), Image.BICUBIC)
    return img

def to_tensor(img):
    return transforms.ToTensor()(img)  # in [0,1]

def to_image(t: torch.Tensor) -> Image.Image:
    t = t.detach().clamp(0,1).cpu()
    return transforms.ToPILImage()(t.squeeze(0))

def normalize_batch(x):
    mean = IMAGENET_MEAN.to(x.device)
    std  = IMAGENET_STD.to(x.device)
    return (x - mean) / std

def gram_matrix(feat: torch.Tensor):
    # feat: [N,C,H,W] -> Gram per sample, normalized by C*H*W
    N, C, H, W = feat.size()
    f = feat.view(N, C, H*W)
    G = torch.bmm(f, f.transpose(1,2)) / (C*H*W)
    return G

def tv_loss(x):
    return (torch.mean(torch.abs(x[..., :, 1:] - x[..., :, :-1])) +
            torch.mean(torch.abs(x[..., 1:, :] - x[..., :-1, :])))

# --------------------- Transform Net (Johnson et al.) ---------------------
class ConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, stride):
        super().__init__()
        pad = kernel // 2
        self.pad = nn.ReflectionPad2d(pad)
        self.conv = nn.Conv2d(in_c, out_c, kernel, stride)
    def forward(self, x):
        return self.conv(self.pad(x))

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv1 = ConvLayer(channels, channels, 3, 1)
        self.in1   = nn.InstanceNorm2d(channels, affine=True)
        self.conv2 = ConvLayer(channels, channels, 3, 1)
        self.in2   = nn.InstanceNorm2d(channels, affine=True)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = self.in2(self.conv2(y))
        return x + y

class UpsampleConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, upsample=None):
        super().__init__()
        self.upsample = upsample
        self.pad = nn.ReflectionPad2d(kernel // 2)
        self.conv = nn.Conv2d(in_c, out_c, kernel, 1)
    def forward(self, x):
        if self.upsample:
            x = F.interpolate(x, scale_factor=self.upsample, mode="nearest")
        return self.conv(self.pad(x))

class TransformNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Encoder
        self.conv1 = ConvLayer(3, 32, 9, 1)
        self.in1   = nn.InstanceNorm2d(32, affine=True)
        self.conv2 = ConvLayer(32, 64, 3, 2)
        self.in2   = nn.InstanceNorm2d(64, affine=True)
        self.conv3 = ConvLayer(64, 128, 3, 2)
        self.in3   = nn.InstanceNorm2d(128, affine=True)
        # Residuals
        self.res   = nn.Sequential(*[ResidualBlock(128) for _ in range(5)])
        # Decoder
        self.up1   = UpsampleConvLayer(128, 64, 3, upsample=2)
        self.in4   = nn.InstanceNorm2d(64, affine=True)
        self.up2   = UpsampleConvLayer(64, 32, 3, upsample=2)
        self.in5   = nn.InstanceNorm2d(32, affine=True)
        self.conv4 = ConvLayer(32, 3, 9, 1)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = F.relu(self.in2(self.conv2(y)))
        y = F.relu(self.in3(self.conv3(y)))
        y = self.res(y)
        y = F.relu(self.in4(self.up1(y)))
        y = F.relu(self.in5(self.up2(y)))
        y = torch.tanh(self.conv4(y))
        return (y + 1) / 2.0  # map from [-1,1] to [0,1]

# --------------------- VGG16 Loss Network ---------------------
class VGG16Features(nn.Module):
    def __init__(self, layers_idx):
        super().__init__()
        vgg = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_FEATURES).features.eval()
        for p in vgg.parameters(): p.requires_grad_(False)
        self.vgg = vgg
        self.layers_idx = layers_idx
    def forward(self, x):
        feats = {}
        for i, layer in enumerate(self.vgg):
            x = layer(x)
            for name, idx in self.layers_idx.items():
                if i == idx:
                    feats[name] = x
        return feats

# --------------------- Dataset ---------------------
class SingleOrFolderDataset(Dataset):
    def __init__(self, content_dir_or_file, image_size):
        super().__init__()
        p = Path(content_dir_or_file)
        if p.is_dir():
            self.paths = [str(pp) for pp in p.glob("*") if pp.suffix.lower() in [".jpg",".png",".jpeg",".bmp",".webp"]]
        else:
            self.paths = [str(p)]
        self.T = transforms.Compose([
            transforms.RandomResizedCrop(image_size, scale=(0.6, 1.0), ratio=(0.75, 1.33)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
        ])
    def __len__(self):
        return max(200, len(self.paths))  # repeat if just one file
    def __getitem__(self, idx):
        p = self.paths[idx % len(self.paths)]
        img = Image.open(p).convert("RGB")
        return self.T(img)

# --------------------- Prep ---------------------
assert Path(CONTENT_IMAGE).exists(), f"Not found: {CONTENT_IMAGE}"
assert Path(STYLE_IMAGE).exists(),   f"Not found: {STYLE_IMAGE}"

device = torch.device(DEVICE)
print("Using device:", device)

# Style targets (Gram matrices of VGG features for the style image)
style_img = load_image(STYLE_IMAGE, size=IMAGE_SIZE)
style_t   = to_tensor(style_img).unsqueeze(0).to(device)
vgg_loss_net = VGG16Features(LAYER_IDX).to(device)
with torch.no_grad():
    style_feats = vgg_loss_net(normalize_batch(style_t))
style_targets = {k: gram_matrix(v).detach() for k, v in style_feats.items() if k in STYLE_LAYERS}

# --------------------- Train Transform Net (per-style) ---------------------
transform_net = TransformNet().to(device)
optim = torch.optim.Adam(transform_net.parameters(), lr=LEARNING_RATE)

ds = SingleOrFolderDataset(CONTENT_DIR if Path(CONTENT_DIR).exists() else CONTENT_IMAGE, IMAGE_SIZE)
loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True, num_workers=2)

print(f"Training on {len(ds)} samples (repeating if needed). Epochs={NUM_EPOCHS}")
global_step = 0
for epoch in range(NUM_EPOCHS):
    t0 = time.time()
    for batch in loader:
        global_step += 1
        batch = batch.to(device)
        optim.zero_grad()

        y_hat = transform_net(batch)                # [0,1]
        y_hat_norm = normalize_batch(y_hat.clone()) # normalize for VGG

        # VGG features
        feats_y_hat = vgg_loss_net(y_hat_norm)
        feats_x     = vgg_loss_net(normalize_batch(batch))

        # Content loss (relu2_2)
        content_loss = F.mse_loss(feats_y_hat[CONTENT_LAYER], feats_x[CONTENT_LAYER])

        # Style loss (sum over layers)
        style_loss = 0.0
        for k in STYLE_LAYERS:
            gm_y = gram_matrix(feats_y_hat[k])
            gm_s = style_targets[k].expand_as(gm_y)
            style_loss += F.mse_loss(gm_y, gm_s)

        # TV regularization
        tv = tv_loss(y_hat)

        loss = CONTENT_WEIGHT * content_loss + STYLE_WEIGHT * style_loss + TV_WEIGHT * tv
        loss.backward()
        optim.step()

        if global_step % 50 == 0:
            print(f"epoch {epoch+1}/{NUM_EPOCHS} step {global_step:05d} | "
                  f"content {content_loss.item():.4f} | style {style_loss.item():.4f} | tv {tv.item():.5f}")

    print(f"Epoch {epoch+1} done in {time.time()-t0:.1f}s")

torch.save(transform_net.state_dict(), MODEL_PATH)
print(f"Saved model to {MODEL_PATH}")

# --------------------- Stylize your content image ---------------------
content_img = load_image(CONTENT_IMAGE, size=IMAGE_SIZE)
content_t   = to_tensor(content_img).unsqueeze(0).to(device)

transform_net.eval()
with torch.no_grad():
    out = transform_net(content_t)

# epoch 2/2 step 23450 | content 81.3604 | style 0.0010 | tv 0.13577
# epoch 2/2 step 23500 | content 77.4795 | style 0.0009 | tv 0.13328
# epoch 2/2 step 23550 | content 79.3219 | style 0.0009 | tv 0.13422
# epoch 2/2 step 23600 | content 86.4766 | style 0.0013 | tv 0.13210
# epoch 2/2 step 23650 | content 73.9877 | style 0.0010 | tv 0.13599
# epoch 2/2 step 23700 | content 76.4318 | style 0.0011 | tv 0.13411
# epoch 2/2 step 23750 | content 95.7469 | style 0.0015 | tv 0.13308
# epoch 2/2 step 23800 | content 78.1707 | style 0.0018 | tv 0.13394
# epoch 2/2 step 23850 | content 87.8218 | style 0.0015 | tv 0.13557
# epoch 2/2 step 23900 | content 76.1710 | style 0.0012 | tv 0.13282
# epoch 2/2 step 23950 | content 90.1911 | style 0.0011 | tv 0.13340
# epoch 2/2 step 24000 | content 74.3136 | style 0.0010 | tv 0.13495
# epoch 2/2 step 24050 | content 83.7102 | style 0.0011 | tv 0.13486
# epoch 2/2 step 24100 | content 81.1636 | style 0.0011 | tv 0.13494
# epoch 2/2 step 24150 | content 75.9288 | style 0.0011 | tv 0.13342
# epoch 2/2 step 24200 | content 83.6612 | style 0.0010 | tv 0.13460
# epoch 2/2 step 24250 | content 81.0701 | style 0.0010 | tv 0.13618
# epoch 2/2 step 24300 | content 89.1092 | style 0.0011 | tv 0.13388
# epoch 2/2 step 24350 | content 74.0706 | style 0.0016 | tv 0.13299
# epoch 2/2 step 24400 | content 81.6383 | style 0.0012 | tv 0.13410
# epoch 2/2 step 24450 | content 82.9740 | style 0.0011 | tv 0.13438
# epoch 2/2 step 24500 | content 74.1515 | style 0.0012 | tv 0.13336
# epoch 2/2 step 24550 | content 80.7062 | style 0.0013 | tv 0.13450
# epoch 2/2 step 24600 | content 75.0046 | style 0.0011 | tv 0.13511
# epoch 2/2 step 24650 | content 73.8854 | style 0.0011 | tv 0.13325
# epoch 2/2 step 24700 | content 86.7562 | style 0.0011 | tv 0.13481
# epoch 2/2 step 24750 | content 75.0191 | style 0.0014 | tv 0.13255
# epoch 2/2 step 24800 | content 77.6202 | style 0.0014 | tv 0.13456
# epoch 2/2 step 24850 | content 84.2053 | style 0.0010 | tv 0.13497
# epoch 2/2 step 24900 | content 77.5289 | style 0.0012 | tv 0.13472
# epoch 2/2 step 24950 | content 82.3357 | style 0.0012 | tv 0.13418
# Epoch 2 done in 4400.0s
# Saved model to transform_net.pth
# Saved stylized image to johnson_stylized2.jpg

# %%
# Inference for Johnson et al. transform net (single-style)
# Inputs:
#   MODEL_PATH: trained weights you saved
#   INPUT_CONTENT: any content image you want to stylize
# Output:
#   OUTPUT_IMAGE: stylized result

import torch
from PIL import Image
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F

MODEL_PATH    = "transform_net.pth"
INPUT_CONTENT = "content test3.jpg"   # <-- put your content image here
OUTPUT_IMAGE  = "stylized_result.jpg"
IMAGE_SIZE    = 512
DEVICE        = "cuda" if torch.cuda.is_available() else "cpu"

# ----- minimal helpers (match training-time scaling [0,1]) -----
def load_image(path, size=None):
    img = Image.open(path).convert("RGB")
    if size is not None:
        img = img.resize((size, size), Image.BICUBIC)
    return img

to_tensor = transforms.ToTensor()
to_pil    = transforms.ToPILImage()

# ----- TransformNet definition (must match what you trained) -----
class ConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, stride):
        super().__init__()
        pad = kernel // 2
        self.pad = nn.ReflectionPad2d(pad)
        self.conv = nn.Conv2d(in_c, out_c, kernel, stride)
    def forward(self, x):
        return self.conv(self.pad(x))

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv1 = ConvLayer(channels, channels, 3, 1)
        self.in1   = nn.InstanceNorm2d(channels, affine=True)
        self.conv2 = ConvLayer(channels, channels, 3, 1)
        self.in2   = nn.InstanceNorm2d(channels, affine=True)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = self.in2(self.conv2(y))
        return x + y

class UpsampleConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, upsample=None):
        super().__init__()
        self.upsample = upsample
        self.pad = nn.ReflectionPad2d(kernel // 2)
        self.conv = nn.Conv2d(in_c, out_c, kernel, 1)
    def forward(self, x):
        if self.upsample:
            x = F.interpolate(x, scale_factor=self.upsample, mode="nearest")
        return self.conv(self.pad(x))

class TransformNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = ConvLayer(3, 32, 9, 1)
        self.in1   = nn.InstanceNorm2d(32, affine=True)
        self.conv2 = ConvLayer(32, 64, 3, 2)
        self.in2   = nn.InstanceNorm2d(64, affine=True)
        self.conv3 = ConvLayer(64, 128, 3, 2)
        self.in3   = nn.InstanceNorm2d(128, affine=True)
        self.res   = nn.Sequential(*[ResidualBlock(128) for _ in range(5)])
        self.up1   = UpsampleConvLayer(128, 64, 3, upsample=2)
        self.in4   = nn.InstanceNorm2d(64, affine=True)
        self.up2   = UpsampleConvLayer(64, 32, 3, upsample=2)
        self.in5   = nn.InstanceNorm2d(32, affine=True)
        self.conv4 = ConvLayer(32, 3, 9, 1)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = F.relu(self.in2(self.conv2(y)))
        y = F.relu(self.in3(self.conv3(y)))
        y = self.res(y)
        y = F.relu(self.in4(self.up1(y)))
        y = F.relu(self.in5(self.up2(y)))
        y = torch.tanh(self.conv4(y))
        return (y + 1) / 2.0

# ----- run inference -----
net = TransformNet().to(DEVICE)
net.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
net.eval()

img = load_image(INPUT_CONTENT, size=IMAGE_SIZE)
t   = to_tensor(img).unsqueeze(0).to(DEVICE)

with torch.no_grad():
    out = net(t).clamp(0,1)

to_pil(out.squeeze(0).cpu()).save(OUTPUT_IMAGE)
print(f"Saved: {OUTPUT_IMAGE}")
# Out:
# Saved: stylized_result.jpg

# %%
# Main Johnson module ( Van Gogh )
import os, math, time, random
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchvision import models, transforms
from PIL import Image
import numpy as np

# --------------------- Config ---------------------
CONTENT_IMAGE = "content test2.jpg"     # (your content path)
STYLE_IMAGE   = "Van_Gogh_-_Starry_Night.jpg"   # (your style path)
OUTPUT_IMAGE  = "johnson_stylized3.jpg"
MODEL_PATH    = "transform_net2.pth"

# Minimal "dataset" defaults to the single content image; point this to a folder for better training
CONTENT_DIR   = "content"       # folder of training content images (e.g., "./coco_subset"); "." uses the single content image
IMAGE_SIZE    = 512       # train/infer resolution (256/512/768). Higher => better quality, slower training
BATCH_SIZE    = 4
NUM_EPOCHS    = 2         # increase (e.g., 2–4) if you have a folder of content images
LEARNING_RATE = 1e-3
SEED          = 42
DEVICE        = "cuda" if torch.cuda.is_available() else "cpu"

# Perceptual loss weights (Johnson et al. typical ranges)
CONTENT_WEIGHT = 0.3
STYLE_WEIGHT   = 2e4
TV_WEIGHT      = 5e-7

# VGG style/content layers (Johnson et al.: content=relu2_2; style=relu1_2, relu2_2, relu3_3, relu4_3)
LAYER_IDX = {
    "relu1_2": 3,
    "relu2_2": 8,
    "relu3_3": 15,
    "relu4_3": 22
}
STYLE_LAYERS   = ["relu1_2","relu2_2","relu3_3","relu4_3"]
CONTENT_LAYER  = "relu2_2"

random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# --------------------- Utils ---------------------
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

def load_image(path, size=None):
    img = Image.open(path).convert("RGB")
    if size is not None:
        img = img.resize((size, size), Image.BICUBIC)
    return img

def to_tensor(img):
    return transforms.ToTensor()(img)  # in [0,1]

def to_image(t: torch.Tensor) -> Image.Image:
    t = t.detach().clamp(0,1).cpu()
    return transforms.ToPILImage()(t.squeeze(0))

def normalize_batch(x):
    mean = IMAGENET_MEAN.to(x.device)
    std  = IMAGENET_STD.to(x.device)
    return (x - mean) / std

def gram_matrix(feat: torch.Tensor):
    # feat: [N,C,H,W] -> Gram per sample, normalized by C*H*W
    N, C, H, W = feat.size()
    f = feat.view(N, C, H*W)
    G = torch.bmm(f, f.transpose(1,2)) / (C*H*W)
    return G

def tv_loss(x):
    return (torch.mean(torch.abs(x[..., :, 1:] - x[..., :, :-1])) +
            torch.mean(torch.abs(x[..., 1:, :] - x[..., :-1, :])))

# --------------------- Transform Net (Johnson et al.) ---------------------
class ConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, stride):
        super().__init__()
        pad = kernel // 2
        self.pad = nn.ReflectionPad2d(pad)
        self.conv = nn.Conv2d(in_c, out_c, kernel, stride)
    def forward(self, x):
        return self.conv(self.pad(x))

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv1 = ConvLayer(channels, channels, 3, 1)
        self.in1   = nn.InstanceNorm2d(channels, affine=True)
        self.conv2 = ConvLayer(channels, channels, 3, 1)
        self.in2   = nn.InstanceNorm2d(channels, affine=True)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = self.in2(self.conv2(y))
        return x + y

class UpsampleConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, upsample=None):
        super().__init__()
        self.upsample = upsample
        self.pad = nn.ReflectionPad2d(kernel // 2)
        self.conv = nn.Conv2d(in_c, out_c, kernel, 1)
    def forward(self, x):
        if self.upsample:
            x = F.interpolate(x, scale_factor=self.upsample, mode="nearest")
        return self.conv(self.pad(x))

class TransformNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Encoder
        self.conv1 = ConvLayer(3, 32, 9, 1)
        self.in1   = nn.InstanceNorm2d(32, affine=True)
        self.conv2 = ConvLayer(32, 64, 3, 2)
        self.in2   = nn.InstanceNorm2d(64, affine=True)
        self.conv3 = ConvLayer(64, 128, 3, 2)
        self.in3   = nn.InstanceNorm2d(128, affine=True)
        # Residuals
        self.res   = nn.Sequential(*[ResidualBlock(128) for _ in range(5)])
        # Decoder
        self.up1   = UpsampleConvLayer(128, 64, 3, upsample=2)
        self.in4   = nn.InstanceNorm2d(64, affine=True)
        self.up2   = UpsampleConvLayer(64, 32, 3, upsample=2)
        self.in5   = nn.InstanceNorm2d(32, affine=True)
        self.conv4 = ConvLayer(32, 3, 9, 1)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = F.relu(self.in2(self.conv2(y)))
        y = F.relu(self.in3(self.conv3(y)))
        y = self.res(y)
        y = F.relu(self.in4(self.up1(y)))
        y = F.relu(self.in5(self.up2(y)))
        y = torch.tanh(self.conv4(y))
        return (y + 1) / 2.0  # map from [-1,1] to [0,1]

# --------------------- VGG16 Loss Network ---------------------
class VGG16Features(nn.Module):
    def __init__(self, layers_idx):
        super().__init__()
        vgg = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_FEATURES).features.eval()
        for p in vgg.parameters(): p.requires_grad_(False)
        self.vgg = vgg
        self.layers_idx = layers_idx
    def forward(self, x):
        feats = {}
        for i, layer in enumerate(self.vgg):
            x = layer(x)
            for name, idx in self.layers_idx.items():
                if i == idx:
                    feats[name] = x
        return feats

# --------------------- Dataset ---------------------
class SingleOrFolderDataset(Dataset):
    def __init__(self, content_dir_or_file, image_size):
        super().__init__()
        p = Path(content_dir_or_file)
        if p.is_dir():
            self.paths = [str(pp) for pp in p.glob("*") if pp.suffix.lower() in [".jpg",".png",".jpeg",".bmp",".webp"]]
        else:
            self.paths = [str(p)]
        self.T = transforms.Compose([
            transforms.RandomResizedCrop(image_size, scale=(0.6, 1.0), ratio=(0.75, 1.33)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
        ])
    def __len__(self):
        return max(200, len(self.paths))  # repeat if just one file
    def __getitem__(self, idx):
        p = self.paths[idx % len(self.paths)]
        img = Image.open(p).convert("RGB")
        return self.T(img)

# --------------------- Prep ---------------------
assert Path(CONTENT_IMAGE).exists(), f"Not found: {CONTENT_IMAGE}"
assert Path(STYLE_IMAGE).exists(),   f"Not found: {STYLE_IMAGE}"

device = torch.device(DEVICE)
print("Using device:", device)

# Style targets (Gram matrices of VGG features for the style image)
style_img = load_image(STYLE_IMAGE, size=IMAGE_SIZE)
style_t   = to_tensor(style_img).unsqueeze(0).to(device)
vgg_loss_net = VGG16Features(LAYER_IDX).to(device)
with torch.no_grad():
    style_feats = vgg_loss_net(normalize_batch(style_t))
style_targets = {k: gram_matrix(v).detach() for k, v in style_feats.items() if k in STYLE_LAYERS}

# --------------------- Train Transform Net (per-style) ---------------------
transform_net = TransformNet().to(device)
optim = torch.optim.Adam(transform_net.parameters(), lr=LEARNING_RATE)

ds = SingleOrFolderDataset(CONTENT_DIR if Path(CONTENT_DIR).exists() else CONTENT_IMAGE, IMAGE_SIZE)
loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True, num_workers=2)

print(f"Training on {len(ds)} samples (repeating if needed). Epochs={NUM_EPOCHS}")
global_step = 0
for epoch in range(NUM_EPOCHS):
    t0 = time.time()
    for batch in loader:
        global_step += 1
        batch = batch.to(device)
        optim.zero_grad()

        y_hat = transform_net(batch)                # [0,1]
        y_hat_norm = normalize_batch(y_hat.clone()) # normalize for VGG

        # VGG features
        feats_y_hat = vgg_loss_net(y_hat_norm)
        feats_x     = vgg_loss_net(normalize_batch(batch))

        # Content loss (relu2_2)
        content_loss = F.mse_loss(feats_y_hat[CONTENT_LAYER], feats_x[CONTENT_LAYER])

        # Style loss (sum over layers)
        style_loss = 0.0
        for k in STYLE_LAYERS:
            gm_y = gram_matrix(feats_y_hat[k])
            gm_s = style_targets[k].expand_as(gm_y)
            style_loss += F.mse_loss(gm_y, gm_s)

        # TV regularization
        tv = tv_loss(y_hat)

        loss = CONTENT_WEIGHT * content_loss + STYLE_WEIGHT * style_loss + TV_WEIGHT * tv
        loss.backward()
        optim.step()

        if global_step % 50 == 0:
            print(f"epoch {epoch+1}/{NUM_EPOCHS} step {global_step:05d} | "
                  f"content {content_loss.item():.4f} | style {style_loss.item():.4f} | tv {tv.item():.5f}")

    print(f"Epoch {epoch+1} done in {time.time()-t0:.1f}s")

torch.save(transform_net.state_dict(), MODEL_PATH)
print(f"Saved model to {MODEL_PATH}")

# --------------------- Stylize your content image ---------------------
content_img = load_image(CONTENT_IMAGE, size=IMAGE_SIZE)
content_t   = to_tensor(content_img).unsqueeze(0).to(device)

transform_net.eval()
with torch.no_grad():
    out = transform_net(content_t)

to_image(out).save(OUTPUT_IMAGE)
print(f"Saved stylized image to {OUTPUT_IMAGE}")
# Out:
# Using device: cuda
# Training on 49981 samples (repeating if needed). Epochs=2
# epoch 1/2 step 00050 | content 89.7276 | style 0.1904 | tv 0.01657
# epoch 1/2 step 00100 | content 111.8093 | style 0.0880 | tv 0.05242
# epoch 1/2 step 00150 | content 174.2180 | style 0.0257 | tv 0.11028
# epoch 1/2 step 00200 | content 171.5444 | style 0.0197 | tv 0.13163
# epoch 1/2 step 00250 | content 183.7618 | style 0.0119 | tv 0.12803
# epoch 1/2 step 00300 | content 153.4534 | style 0.0089 | tv 0.13070
# epoch 1/2 step 00350 | content 167.8714 | style 0.0079 | tv 0.12718
# epoch 1/2 step 00400 | content 153.0028 | style 0.0071 | tv 0.13008
# epoch 1/2 step 00450 | content 181.9163 | style 0.0056 | tv 0.13547
# epoch 1/2 step 00500 | content 165.8787 | style 0.0051 | tv 0.13324
# epoch 1/2 step 00550 | content 166.4273 | style 0.0045 | tv 0.13566
# epoch 1/2 step 00600 | content 178.4802 | style 0.0051 | tv 0.13308
# epoch 1/2 step 00650 | content 182.4744 | style 0.0041 | tv 0.13657
# epoch 1/2 step 00700 | content 168.4446 | style 0.0064 | tv 0.13094
# epoch 1/2 step 00750 | content 152.6571 | style 0.0037 | tv 0.13334
# epoch 1/2 step 00800 | content 171.3159 | style 0.0033 | tv 0.13625
# epoch 1/2 step 00850 | content 152.5029 | style 0.0032 | tv 0.13546
# epoch 1/2 step 00900 | content 153.8589 | style 0.0026 | tv 0.13492
# epoch 1/2 step 00950 | content 152.8662 | style 0.0026 | tv 0.13553
# epoch 1/2 step 01000 | content 157.9355 | style 0.0028 | tv 0.13424
# epoch 1/2 step 01050 | content 141.7784 | style 0.0028 | tv 0.13744
# epoch 1/2 step 01100 | content 152.9994 | style 0.0028 | tv 0.13328
# epoch 1/2 step 01150 | content 155.9481 | style 0.0022 | tv 0.13460
# epoch 1/2 step 01200 | content 156.0112 | style 0.0023 | tv 0.13624
# epoch 1/2 step 01250 | content 168.7415 | style 0.0027 | tv 0.13623
# epoch 1/2 step 01300 | content 152.5839 | style 0.0022 | tv 0.13669
# epoch 1/2 step 01350 | content 156.2969 | style 0.0021 | tv 0.13343
# epoch 1/2 step 01400 | content 157.2884 | style 0.0020 | tv 0.13372
# epoch 1/2 step 01450 | content 155.7467 | style 0.0018 | tv 0.13547
# epoch 1/2 step 01500 | content 156.7247 | style 0.0022 | tv 0.13470
# epoch 1/2 step 01550 | content 151.7766 | style 0.0019 | tv 0.13384
# epoch 1/2 step 01600 | content 157.0737 | style 0.0018 | tv 0.13534
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchvision import models, transforms
from PIL import Image
import numpy as np

# --------------------- Config ---------------------
CONTENT_IMAGE = "content test2.jpg"     # (your content path)
STYLE_IMAGE   = "Van_Gogh_-_Starry_Night.jpg"   # (your style path)
OUTPUT_IMAGE  = "johnson_stylized5.jpg"
MODEL_PATH    = "transform_net4.pth"

# Minimal "dataset" defaults to the single content image; point this to a folder for better training
CONTENT_DIR   = "content"       # folder of training content images (e.g., "./coco_subset"); "." uses the single content image
IMAGE_SIZE    = 512       # train/infer resolution (256/512/768). Higher => better quality, slower training
BATCH_SIZE    = 4
NUM_EPOCHS    = 2         # increase (e.g., 2–4) if you have a folder of content images
LEARNING_RATE = 1e-3
SEED          = 42
DEVICE        = "cuda" if torch.cuda.is_available() else "cpu"

# Perceptual loss weights (Johnson et al. typical ranges)
CONTENT_WEIGHT = 1.0
STYLE_WEIGHT   = 5e3
TV_WEIGHT      = 1e-6

# VGG style/content layers (Johnson et al.: content=relu2_2; style=relu1_2, relu2_2, relu3_3, relu4_3)
LAYER_IDX = {
    "relu1_2": 3,
    "relu2_2": 8,
    "relu3_3": 15,
    "relu4_3": 22
}
STYLE_LAYERS   = ["relu1_2","relu2_2","relu3_3","relu4_3"]
CONTENT_LAYER  = "relu2_2"

random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# --------------------- Utils ---------------------
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

def load_image(path, size=None):
    img = Image.open(path).convert("RGB")
    if size is not None:
        img = img.resize((size, size), Image.BICUBIC)
    return img

def to_tensor(img):
    return transforms.ToTensor()(img)  # in [0,1]

def to_image(t: torch.Tensor) -> Image.Image:
    t = t.detach().clamp(0,1).cpu()
    return transforms.ToPILImage()(t.squeeze(0))

def normalize_batch(x):
    mean = IMAGENET_MEAN.to(x.device)
    std  = IMAGENET_STD.to(x.device)
    return (x - mean) / std

def gram_matrix(feat: torch.Tensor):
    # feat: [N,C,H,W] -> Gram per sample, normalized by C*H*W
    N, C, H, W = feat.size()
    f = feat.view(N, C, H*W)
    G = torch.bmm(f, f.transpose(1,2)) / (C*H*W)
    return G

def tv_loss(x):
    return (torch.mean(torch.abs(x[..., :, 1:] - x[..., :, :-1])) +
            torch.mean(torch.abs(x[..., 1:, :] - x[..., :-1, :])))

# --------------------- Transform Net (Johnson et al.) ---------------------
class ConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, stride):
        super().__init__()
        pad = kernel // 2
        self.pad = nn.ReflectionPad2d(pad)
        self.conv = nn.Conv2d(in_c, out_c, kernel, stride)
    def forward(self, x):
        return self.conv(self.pad(x))

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv1 = ConvLayer(channels, channels, 3, 1)
        self.in1   = nn.InstanceNorm2d(channels, affine=True)
        self.conv2 = ConvLayer(channels, channels, 3, 1)
        self.in2   = nn.InstanceNorm2d(channels, affine=True)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = self.in2(self.conv2(y))
        return x + y

class UpsampleConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, upsample=None):
        super().__init__()
        self.upsample = upsample
        self.pad = nn.ReflectionPad2d(kernel // 2)
        self.conv = nn.Conv2d(in_c, out_c, kernel, 1)
    def forward(self, x):
        if self.upsample:
            x = F.interpolate(x, scale_factor=self.upsample, mode="nearest")
        return self.conv(self.pad(x))

class TransformNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Encoder
        self.conv1 = ConvLayer(3, 32, 9, 1)
        self.in1   = nn.InstanceNorm2d(32, affine=True)
        self.conv2 = ConvLayer(32, 64, 3, 2)
        self.in2   = nn.InstanceNorm2d(64, affine=True)
        self.conv3 = ConvLayer(64, 128, 3, 2)
        self.in3   = nn.InstanceNorm2d(128, affine=True)
        # Residuals
        self.res   = nn.Sequential(*[ResidualBlock(128) for _ in range(5)])
        # Decoder
        self.up1   = UpsampleConvLayer(128, 64, 3, upsample=2)
        self.in4   = nn.InstanceNorm2d(64, affine=True)
        self.up2   = UpsampleConvLayer(64, 32, 3, upsample=2)
        self.in5   = nn.InstanceNorm2d(32, affine=True)
        self.conv4 = ConvLayer(32, 3, 9, 1)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = F.relu(self.in2(self.conv2(y)))
        y = F.relu(self.in3(self.conv3(y)))
        y = self.res(y)
        y = F.relu(self.in4(self.up1(y)))
        y = F.relu(self.in5(self.up2(y)))
        y = torch.tanh(self.conv4(y))
        return (y + 1) / 2.0  # map from [-1,1] to [0,1]

# --------------------- VGG16 Loss Network ---------------------
class VGG16Features(nn.Module):
    def __init__(self, layers_idx):
        super().__init__()
        vgg = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_FEATURES).features.eval()
        for p in vgg.parameters(): p.requires_grad_(False)
        self.vgg = vgg
        self.layers_idx = layers_idx
    def forward(self, x):
        feats = {}
        for i, layer in enumerate(self.vgg):
            x = layer(x)
            for name, idx in self.layers_idx.items():
                if i == idx:
                    feats[name] = x
        return feats

# --------------------- Dataset ---------------------
class SingleOrFolderDataset(Dataset):
    def __init__(self, content_dir_or_file, image_size):
        super().__init__()
        p = Path(content_dir_or_file)
        if p.is_dir():
            self.paths = [str(pp) for pp in p.glob("*") if pp.suffix.lower() in [".jpg",".png",".jpeg",".bmp",".webp"]]
        else:
            self.paths = [str(p)]
        self.T = transforms.Compose([
            transforms.RandomResizedCrop(image_size, scale=(0.6, 1.0), ratio=(0.75, 1.33)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
        ])
    def __len__(self):
        return max(200, len(self.paths))  # repeat if just one file
    def __getitem__(self, idx):
        p = self.paths[idx % len(self.paths)]
        img = Image.open(p).convert("RGB")
        return self.T(img)

# --------------------- Prep ---------------------
assert Path(CONTENT_IMAGE).exists(), f"Not found: {CONTENT_IMAGE}"
assert Path(STYLE_IMAGE).exists(),   f"Not found: {STYLE_IMAGE}"

device = torch.device(DEVICE)
print("Using device:", device)

# Style targets (Gram matrices of VGG features for the style image)
style_img = load_image(STYLE_IMAGE, size=IMAGE_SIZE)
style_t   = to_tensor(style_img).unsqueeze(0).to(device)
vgg_loss_net = VGG16Features(LAYER_IDX).to(device)
with torch.no_grad():
    style_feats = vgg_loss_net(normalize_batch(style_t))
style_targets = {k: gram_matrix(v).detach() for k, v in style_feats.items() if k in STYLE_LAYERS}

# --------------------- Train Transform Net (per-style) ---------------------
transform_net = TransformNet().to(device)
optim = torch.optim.Adam(transform_net.parameters(), lr=LEARNING_RATE)

ds = SingleOrFolderDataset(CONTENT_DIR if Path(CONTENT_DIR).exists() else CONTENT_IMAGE, IMAGE_SIZE)
loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True, num_workers=2)

print(f"Training on {len(ds)} samples (repeating if needed). Epochs={NUM_EPOCHS}")
global_step = 0
for epoch in range(NUM_EPOCHS):
    t0 = time.time()
    for batch in loader:
        global_step += 1
        batch = batch.to(device)
        optim.zero_grad()

        y_hat = transform_net(batch)                # [0,1]
        y_hat_norm = normalize_batch(y_hat.clone()) # normalize for VGG

        # VGG features
        feats_y_hat = vgg_loss_net(y_hat_norm)
        feats_x     = vgg_loss_net(normalize_batch(batch))

        # Content loss (relu2_2)
        content_loss = F.mse_loss(feats_y_hat[CONTENT_LAYER], feats_x[CONTENT_LAYER])

        # Style loss (sum over layers)
        style_loss = 0.0
        for k in STYLE_LAYERS:
            gm_y = gram_matrix(feats_y_hat[k])
            gm_s = style_targets[k].expand_as(gm_y)
            style_loss += F.mse_loss(gm_y, gm_s)

        # TV regularization
        tv = tv_loss(y_hat)

        loss = CONTENT_WEIGHT * content_loss + STYLE_WEIGHT * style_loss + TV_WEIGHT * tv
        loss.backward()
        optim.step()

        if global_step % 50 == 0:
            print(f"epoch {epoch+1}/{NUM_EPOCHS} step {global_step:05d} | "
                  f"content {content_loss.item():.4f} | style {style_loss.item():.4f} | tv {tv.item():.5f}")

    print(f"Epoch {epoch+1} done in {time.time()-t0:.1f}s")

torch.save(transform_net.state_dict(), MODEL_PATH)
print(f"Saved model to {MODEL_PATH}")

# --------------------- Stylize your content image ---------------------
content_img = load_image(CONTENT_IMAGE, size=IMAGE_SIZE)
content_t   = to_tensor(content_img).unsqueeze(0).to(device)

transform_net.eval()
with torch.no_grad():
    out = transform_net(content_t)

to_image(out).save(OUTPUT_IMAGE)
print(f"Saved stylized image to {OUTPUT_IMAGE}")
# Out:
# Using device: cuda
# Training on 49981 samples (repeating if needed). Epochs=2
# epoch 1/2 step 00050 | content 86.1079 | style 0.1638 | tv 0.02250
# epoch 1/2 step 00100 | content 116.9638 | style 0.0531 | tv 0.07404
# epoch 2/2 step 23700 | content 51.8432 | style 0.0026 | tv 0.14783
# epoch 2/2 step 23750 | content 72.3609 | style 0.0035 | tv 0.15171
# epoch 2/2 step 23800 | content 52.4224 | style 0.0038 | tv 0.14512
# epoch 2/2 step 23850 | content 63.5753 | style 0.0035 | tv 0.15325
# epoch 2/2 step 23900 | content 51.9049 | style 0.0031 | tv 0.14227
# epoch 2/2 step 23950 | content 66.7434 | style 0.0030 | tv 0.14733
# epoch 2/2 step 24000 | content 49.5695 | style 0.0023 | tv 0.14842
# epoch 2/2 step 24050 | content 59.2723 | style 0.0027 | tv 0.15137
# epoch 2/2 step 24100 | content 56.6566 | style 0.0027 | tv 0.14738
# epoch 2/2 step 24150 | content 50.7664 | style 0.0028 | tv 0.14804
# epoch 2/2 step 24200 | content 57.5491 | style 0.0029 | tv 0.14819
# epoch 2/2 step 24250 | content 59.7299 | style 0.0027 | tv 0.15600
# epoch 2/2 step 24300 | content 65.2849 | style 0.0028 | tv 0.15047
# epoch 2/2 step 24350 | content 53.9898 | style 0.0031 | tv 0.14949
# epoch 2/2 step 24400 | content 55.8929 | style 0.0031 | tv 0.14582
# epoch 2/2 step 24450 | content 67.5024 | style 0.0034 | tv 0.14834
# epoch 2/2 step 24500 | content 56.8255 | style 0.0025 | tv 0.14967
# epoch 2/2 step 24550 | content 58.3310 | style 0.0034 | tv 0.15432
# epoch 2/2 step 24600 | content 53.9431 | style 0.0026 | tv 0.15326
# epoch 2/2 step 24650 | content 54.1432 | style 0.0026 | tv 0.14930
# epoch 2/2 step 24700 | content 67.6253 | style 0.0031 | tv 0.15220
# epoch 2/2 step 24750 | content 60.7801 | style 0.0041 | tv 0.14657
# epoch 2/2 step 24800 | content 57.5120 | style 0.0034 | tv 0.15232
# epoch 2/2 step 24850 | content 63.2364 | style 0.0031 | tv 0.14859
# epoch 2/2 step 24900 | content 57.6497 | style 0.0030 | tv 0.15072
# epoch 2/2 step 24950 | content 61.7040 | style 0.0028 | tv 0.14797
# Epoch 2 done in 4403.6s
# Saved model to transform_net4.pth
# Saved stylized image to johnson_stylized5.jpg

# %%
# kandinsky Module
import os, math, time, random
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchvision import models, transforms
from PIL import Image
import numpy as np

# --------------------- Config ---------------------
CONTENT_IMAGE = "content test2.jpg"     # (your content path)
STYLE_IMAGE   = "kandinsky style.jpg"   # (your style path)
OUTPUT_IMAGE  = "kandinsky_johnson_stylized.jpg"
MODEL_PATH    = "kandinsky_transform_net.pth"

# Minimal "dataset" defaults to the single content image; point this to a folder for better training
CONTENT_DIR   = "content"       # folder of training content images (e.g., "./coco_subset"); "." uses the single content image
IMAGE_SIZE    = 512       # train/infer resolution (256/512/768). Higher => better quality, slower training
BATCH_SIZE    = 4
NUM_EPOCHS    = 2         # increase (e.g., 2–4) if you have a folder of content images
LEARNING_RATE = 1e-3
SEED          = 42
DEVICE        = "cuda" if torch.cuda.is_available() else "cpu"

# Perceptual loss weights (Johnson et al. typical ranges)
CONTENT_WEIGHT = 0.5
STYLE_WEIGHT   = 1e4      # try 5e3–1e4; if style is weak, raise this
TV_WEIGHT      = 1e-6

# VGG style/content layers (Johnson et al.: content=relu2_2; style=relu1_2, relu2_2, relu3_3, relu4_3)
LAYER_IDX = {
    "relu1_2": 3,
    "relu2_2": 8,
    "relu3_3": 15,
    "relu4_3": 22
}
STYLE_LAYERS   = ["relu1_2","relu2_2","relu3_3","relu4_3"]
CONTENT_LAYER  = "relu2_2"

random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# --------------------- Utils ---------------------
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

def load_image(path, size=None):
    img = Image.open(path).convert("RGB")
    if size is not None:
        img = img.resize((size, size), Image.BICUBIC)
    return img

def to_tensor(img):
    return transforms.ToTensor()(img)  # in [0,1]

def to_image(t: torch.Tensor) -> Image.Image:
    t = t.detach().clamp(0,1).cpu()
    return transforms.ToPILImage()(t.squeeze(0))

def normalize_batch(x):
    mean = IMAGENET_MEAN.to(x.device)
    std  = IMAGENET_STD.to(x.device)
    return (x - mean) / std

def gram_matrix(feat: torch.Tensor):
    # feat: [N,C,H,W] -> Gram per sample, normalized by C*H*W
    N, C, H, W = feat.size()
    f = feat.view(N, C, H*W)
    G = torch.bmm(f, f.transpose(1,2)) / (C*H*W)
    return G

def tv_loss(x):
    return (torch.mean(torch.abs(x[..., :, 1:] - x[..., :, :-1])) +
            torch.mean(torch.abs(x[..., 1:, :] - x[..., :-1, :])))

# --------------------- Transform Net (Johnson et al.) ---------------------
class ConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, stride):
        super().__init__()
        pad = kernel // 2
        self.pad = nn.ReflectionPad2d(pad)
        self.conv = nn.Conv2d(in_c, out_c, kernel, stride)
    def forward(self, x):
        return self.conv(self.pad(x))

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv1 = ConvLayer(channels, channels, 3, 1)
        self.in1   = nn.InstanceNorm2d(channels, affine=True)
        self.conv2 = ConvLayer(channels, channels, 3, 1)
        self.in2   = nn.InstanceNorm2d(channels, affine=True)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = self.in2(self.conv2(y))
        return x + y

class UpsampleConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, upsample=None):
        super().__init__()
        self.upsample = upsample
        self.pad = nn.ReflectionPad2d(kernel // 2)
        self.conv = nn.Conv2d(in_c, out_c, kernel, 1)
    def forward(self, x):
        if self.upsample:
            x = F.interpolate(x, scale_factor=self.upsample, mode="nearest")
        return self.conv(self.pad(x))

class TransformNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Encoder
        self.conv1 = ConvLayer(3, 32, 9, 1)
        self.in1   = nn.InstanceNorm2d(32, affine=True)
        self.conv2 = ConvLayer(32, 64, 3, 2)
        self.in2   = nn.InstanceNorm2d(64, affine=True)
        self.conv3 = ConvLayer(64, 128, 3, 2)
        self.in3   = nn.InstanceNorm2d(128, affine=True)
        # Residuals
        self.res   = nn.Sequential(*[ResidualBlock(128) for _ in range(5)])
        # Decoder
        self.up1   = UpsampleConvLayer(128, 64, 3, upsample=2)
        self.in4   = nn.InstanceNorm2d(64, affine=True)
        self.up2   = UpsampleConvLayer(64, 32, 3, upsample=2)
        self.in5   = nn.InstanceNorm2d(32, affine=True)
        self.conv4 = ConvLayer(32, 3, 9, 1)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = F.relu(self.in2(self.conv2(y)))
        y = F.relu(self.in3(self.conv3(y)))
        y = self.res(y)
        y = F.relu(self.in4(self.up1(y)))
        y = F.relu(self.in5(self.up2(y)))
        y = torch.tanh(self.conv4(y))
        return (y + 1) / 2.0  # map from [-1,1] to [0,1]

# --------------------- VGG16 Loss Network ---------------------
class VGG16Features(nn.Module):
    def __init__(self, layers_idx):
        super().__init__()
        vgg = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_FEATURES).features.eval()
        for p in vgg.parameters(): p.requires_grad_(False)
        self.vgg = vgg
        self.layers_idx = layers_idx
    def forward(self, x):
        feats = {}
        for i, layer in enumerate(self.vgg):
            x = layer(x)
            for name, idx in self.layers_idx.items():
                if i == idx:
                    feats[name] = x
        return feats

# --------------------- Dataset ---------------------
class SingleOrFolderDataset(Dataset):
    def __init__(self, content_dir_or_file, image_size):
        super().__init__()
        p = Path(content_dir_or_file)
        if p.is_dir():
            self.paths = [str(pp) for pp in p.glob("*") if pp.suffix.lower() in [".jpg",".png",".jpeg",".bmp",".webp"]]
        else:
            self.paths = [str(p)]
        self.T = transforms.Compose([
            transforms.RandomResizedCrop(image_size, scale=(0.6, 1.0), ratio=(0.75, 1.33)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
        ])
    def __len__(self):
        return max(200, len(self.paths))  # repeat if just one file
    def __getitem__(self, idx):
        p = self.paths[idx % len(self.paths)]
        img = Image.open(p).convert("RGB")
        return self.T(img)

# --------------------- Prep ---------------------
assert Path(CONTENT_IMAGE).exists(), f"Not found: {CONTENT_IMAGE}"
assert Path(STYLE_IMAGE).exists(),   f"Not found: {STYLE_IMAGE}"

device = torch.device(DEVICE)
print("Using device:", device)

# Style targets (Gram matrices of VGG features for the style image)
style_img = load_image(STYLE_IMAGE, size=IMAGE_SIZE)
style_t   = to_tensor(style_img).unsqueeze(0).to(device)
vgg_loss_net = VGG16Features(LAYER_IDX).to(device)
with torch.no_grad():
    style_feats = vgg_loss_net(normalize_batch(style_t))
style_targets = {k: gram_matrix(v).detach() for k, v in style_feats.items() if k in STYLE_LAYERS}

# --------------------- Train Transform Net (per-style) ---------------------
transform_net = TransformNet().to(device)
optim = torch.optim.Adam(transform_net.parameters(), lr=LEARNING_RATE)

ds = SingleOrFolderDataset(CONTENT_DIR if Path(CONTENT_DIR).exists() else CONTENT_IMAGE, IMAGE_SIZE)
loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True, num_workers=2)

print(f"Training on {len(ds)} samples (repeating if needed). Epochs={NUM_EPOCHS}")
global_step = 0
for epoch in range(NUM_EPOCHS):
    t0 = time.time()
    for batch in loader:
        global_step += 1
        batch = batch.to(device)
        optim.zero_grad()

        y_hat = transform_net(batch)                # [0,1]
        y_hat_norm = normalize_batch(y_hat.clone()) # normalize for VGG

        # VGG features
        feats_y_hat = vgg_loss_net(y_hat_norm)
        feats_x     = vgg_loss_net(normalize_batch(batch))

        # Content loss (relu2_2)
        content_loss = F.mse_loss(feats_y_hat[CONTENT_LAYER], feats_x[CONTENT_LAYER])

        # Style loss (sum over layers)
        style_loss = 0.0
        for k in STYLE_LAYERS:
            gm_y = gram_matrix(feats_y_hat[k])
            gm_s = style_targets[k].expand_as(gm_y)
            style_loss += F.mse_loss(gm_y, gm_s)

        # TV regularization
        tv = tv_loss(y_hat)

        loss = CONTENT_WEIGHT * content_loss + STYLE_WEIGHT * style_loss + TV_WEIGHT * tv
        loss.backward()
        optim.step()

        if global_step % 50 == 0:
            print(f"epoch {epoch+1}/{NUM_EPOCHS} step {global_step:05d} | "
                  f"content {content_loss.item():.4f} | style {style_loss.item():.4f} | tv {tv.item():.5f}")

    print(f"Epoch {epoch+1} done in {time.time()-t0:.1f}s")

torch.save(transform_net.state_dict(), MODEL_PATH)
print(f"Saved model to {MODEL_PATH}")

# --------------------- Stylize your content image ---------------------
content_img = load_image(CONTENT_IMAGE, size=IMAGE_SIZE)
content_t   = to_tensor(content_img).unsqueeze(0).to(device)

transform_net.eval()
with torch.no_grad():
    out = transform_net(content_t)

to_image(out).save(OUTPUT_IMAGE)
print(f"Saved stylized image to {OUTPUT_IMAGE}")
# Out:
# Using device: cuda
# Training on 49981 samples (repeating if needed). Epochs=2
# epoch 1/2 step 00050 | content 214.3441 | style 0.1052 | tv 0.05966
# epoch 1/2 step 00100 | content 250.9243 | style 0.0377 | tv 0.08799
# epoch 1/2 step 00150 | content 255.2714 | style 0.0332 | tv 0.09363
# epoch 1/2 step 00200 | content 258.5710 | style 0.0263 | tv 0.10379
# epoch 1/2 step 00250 | content 276.2679 | style 0.0179 | tv 0.10499
# epoch 1/2 step 00300 | content 239.4314 | style 0.0156 | tv 0.10274
# epoch 1/2 step 00350 | content 248.5527 | style 0.0134 | tv 0.10206
# epoch 1/2 step 00400 | content 232.0596 | style 0.0160 | tv 0.09910
# epoch 1/2 step 00450 | content 252.0291 | style 0.0106 | tv 0.10957
# epoch 1/2 step 00500 | content 238.8265 | style 0.0120 | tv 0.10728
# epoch 1/2 step 00550 | content 239.7148 | style 0.0101 | tv 0.11011
# epoch 1/2 step 12350 | content 173.3987 | style 0.0027 | tv 0.10985
# epoch 1/2 step 12400 | content 162.4698 | style 0.0030 | tv 0.10866
# epoch 1/2 step 12450 | content 172.4494 | style 0.0028 | tv 0.10952
# Epoch 1 done in 4399.5s
# epoch 2/2 step 12500 | content 169.5874 | style 0.0022 | tv 0.10962
# epoch 2/2 step 12550 | content 173.9603 | style 0.0032 | tv 0.10887
# epoch 2/2 step 12600 | content 173.9839 | style 0.0030 | tv 0.11217
# epoch 2/2 step 12650 | content 170.3682 | style 0.0023 | tv 0.10942
# epoch 2/2 step 12700 | content 168.4665 | style 0.0028 | tv 0.10964
# epoch 2/2 step 12750 | content 165.6136 | style 0.0030 | tv 0.10997
# epoch 2/2 step 12800 | content 159.7186 | style 0.0028 | tv 0.11132
# epoch 2/2 step 12850 | content 167.3511 | style 0.0027 | tv 0.11104
# epoch 2/2 step 12900 | content 173.0725 | style 0.0029 | tv 0.10858
# epoch 2/2 step 12950 | content 170.3476 | style 0.0024 | tv 0.10906
# epoch 2/2 step 13000 | content 170.3997 | style 0.0025 | tv 0.10893
# epoch 2/2 step 13050 | content 161.6531 | style 0.0031 | tv 0.11086
# epoch 2/2 step 13100 | content 168.2304 | style 0.0030 | tv 0.10877
# epoch 2/2 step 13150 | content 169.5396 | style 0.0032 | tv 0.10934
# epoch 2/2 step 13200 | content 157.0940 | style 0.0023 | tv 0.11111
# epoch 2/2 step 13250 | content 155.8810 | style 0.0026 | tv 0.11044
# epoch 2/2 step 13300 | content 164.7480 | style 0.0026 | tv 0.11011
# epoch 2/2 step 13350 | content 173.7710 | style 0.0033 | tv 0.11086
# epoch 2/2 step 13400 | content 165.7824 | style 0.0024 | tv 0.10887
# epoch 2/2 step 13450 | content 165.3148 | style 0.0037 | tv 0.10868
# epoch 2/2 step 13500 | content 168.2544 | style 0.0023 | tv 0.11015
# epoch 2/2 step 13550 | content 160.3704 | style 0.0035 | tv 0.10859
# epoch 2/2 step 13600 | content 168.9842 | style 0.0030 | tv 0.10960
# epoch 2/2 step 13650 | content 181.7209 | style 0.0026 | tv 0.10785
# epoch 2/2 step 13700 | content 184.2033 | style 0.0028 | tv 0.10915
# epoch 2/2 step 13750 | content 174.4334 | style 0.0024 | tv 0.11027
# epoch 2/2 step 13800 | content 168.8686 | style 0.0025 | tv 0.10862
# epoch 2/2 step 13850 | content 162.3043 | style 0.0031 | tv 0.10955
# epoch 2/2 step 13900 | content 168.4269 | style 0.0024 | tv 0.11028
# epoch 2/2 step 13950 | content 161.0124 | style 0.0030 | tv 0.10901
# epoch 2/2 step 14000 | content 147.6807 | style 0.0027 | tv 0.10949
# epoch 2/2 step 14050 | content 166.8535 | style 0.0026 | tv 0.10837
# epoch 2/2 step 14100 | content 177.6867 | style 0.0028 | tv 0.10866
# epoch 2/2 step 14150 | content 170.3852 | style 0.0031 | tv 0.10867
# epoch 2/2 step 14200 | content 168.4378 | style 0.0026 | tv 0.10907
# epoch 2/2 step 14250 | content 165.3102 | style 0.0025 | tv 0.11012
# epoch 2/2 step 14300 | content 174.4879 | style 0.0029 | tv 0.10903
# epoch 2/2 step 14350 | content 172.4667 | style 0.0025 | tv 0.10897
# epoch 2/2 step 14400 | content 176.4257 | style 0.0032 | tv 0.10991
# epoch 2/2 step 14450 | content 164.3792 | style 0.0025 | tv 0.11121
# epoch 2/2 step 14500 | content 165.9032 | style 0.0030 | tv 0.10945
# epoch 2/2 step 14550 | content 168.8141 | style 0.0042 | tv 0.10580
# epoch 2/2 step 14600 | content 175.6577 | style 0.0029 | tv 0.10900
# epoch 2/2 step 14650 | content 163.5282 | style 0.0023 | tv 0.10914
# epoch 2/2 step 14700 | content 162.1131 | style 0.0036 | tv 0.10904
# epoch 2/2 step 14750 | content 155.7900 | style 0.0022 | tv 0.10990
# epoch 2/2 step 14800 | content 170.8591 | style 0.0027 | tv 0.11215
# epoch 2/2 step 14850 | content 152.8003 | style 0.0029 | tv 0.10990
# epoch 2/2 step 14900 | content 164.7570 | style 0.0024 | tv 0.10908
# epoch 2/2 step 14950 | content 164.4308 | style 0.0031 | tv 0.11006
# epoch 2/2 step 15000 | content 158.7104 | style 0.0024 | tv 0.10856
# epoch 2/2 step 15050 | content 152.0064 | style 0.0026 | tv 0.11042
# epoch 2/2 step 15100 | content 170.4077 | style 0.0022 | tv 0.11091
# epoch 2/2 step 15150 | content 161.8038 | style 0.0024 | tv 0.11145
# epoch 2/2 step 15200 | content 169.8449 | style 0.0027 | tv 0.10968
# epoch 2/2 step 15250 | content 164.1372 | style 0.0025 | tv 0.10981
# epoch 2/2 step 15300 | content 166.3102 | style 0.0028 | tv 0.10861
# epoch 2/2 step 15350 | content 163.4342 | style 0.0028 | tv 0.11042
# epoch 2/2 step 15400 | content 167.1919 | style 0.0029 | tv 0.11047
# epoch 2/2 step 15450 | content 158.4020 | style 0.0030 | tv 0.10913
# epoch 2/2 step 15500 | content 154.8511 | style 0.0028 | tv 0.10959
# epoch 2/2 step 15550 | content 160.6181 | style 0.0028 | tv 0.10947
# epoch 2/2 step 15600 | content 165.4449 | style 0.0028 | tv 0.10962
# epoch 2/2 step 15650 | content 162.0117 | style 0.0026 | tv 0.11047
# epoch 2/2 step 15700 | content 175.3364 | style 0.0029 | tv 0.10869
# epoch 2/2 step 15750 | content 166.2328 | style 0.0028 | tv 0.10883
# epoch 2/2 step 15800 | content 174.0038 | style 0.0021 | tv 0.10888
# epoch 2/2 step 15850 | content 150.8462 | style 0.0027 | tv 0.11132
# epoch 2/2 step 15900 | content 166.4632 | style 0.0023 | tv 0.10943
# epoch 2/2 step 15950 | content 149.3560 | style 0.0028 | tv 0.11014
# epoch 2/2 step 16000 | content 157.5874 | style 0.0029 | tv 0.11062
# epoch 2/2 step 16050 | content 160.1708 | style 0.0025 | tv 0.10879
# epoch 2/2 step 16100 | content 169.6638 | style 0.0031 | tv 0.10896
# epoch 2/2 step 16150 | content 168.8080 | style 0.0033 | tv 0.10896
# epoch 2/2 step 16200 | content 161.6618 | style 0.0026 | tv 0.10915
# epoch 2/2 step 16250 | content 169.8190 | style 0.0026 | tv 0.10881
# epoch 2/2 step 16300 | content 165.6670 | style 0.0023 | tv 0.11044
# epoch 2/2 step 16350 | content 165.7442 | style 0.0021 | tv 0.10942
# epoch 2/2 step 16400 | content 180.1821 | style 0.0028 | tv 0.11061
# epoch 2/2 step 16450 | content 159.6346 | style 0.0023 | tv 0.10982
# epoch 2/2 step 16500 | content 156.5259 | style 0.0027 | tv 0.11076
# epoch 2/2 step 16550 | content 165.2099 | style 0.0022 | tv 0.11068
# epoch 2/2 step 16600 | content 153.0603 | style 0.0021 | tv 0.10871
# epoch 2/2 step 16650 | content 156.0457 | style 0.0025 | tv 0.10931
# epoch 2/2 step 16700 | content 155.6720 | style 0.0027 | tv 0.10907
# epoch 2/2 step 16750 | content 152.3511 | style 0.0026 | tv 0.11000
# epoch 2/2 step 16800 | content 173.0897 | style 0.0041 | tv 0.10875
# epoch 2/2 step 16850 | content 157.1054 | style 0.0021 | tv 0.11017
# epoch 2/2 step 16900 | content 155.3591 | style 0.0023 | tv 0.11015
# epoch 2/2 step 16950 | content 147.9503 | style 0.0024 | tv 0.11142
# epoch 2/2 step 17000 | content 166.4590 | style 0.0025 | tv 0.10892
# epoch 2/2 step 17050 | content 158.7103 | style 0.0026 | tv 0.11077
# epoch 2/2 step 17100 | content 148.1145 | style 0.0025 | tv 0.10867
# epoch 2/2 step 17150 | content 169.7460 | style 0.0024 | tv 0.10854
# epoch 2/2 step 17200 | content 161.0094 | style 0.0025 | tv 0.10941
# epoch 2/2 step 17250 | content 159.1561 | style 0.0027 | tv 0.11128
# epoch 2/2 step 17300 | content 153.0856 | style 0.0024 | tv 0.10937
# epoch 2/2 step 17350 | content 169.2710 | style 0.0024 | tv 0.10963
# epoch 2/2 step 17400 | content 163.5187 | style 0.0029 | tv 0.10946
# epoch 2/2 step 17450 | content 165.4310 | style 0.0026 | tv 0.10947
# epoch 2/2 step 17500 | content 166.9842 | style 0.0025 | tv 0.10882
# epoch 2/2 step 17550 | content 157.1303 | style 0.0028 | tv 0.10924
# epoch 2/2 step 17600 | content 163.5946 | style 0.0031 | tv 0.10822
# epoch 2/2 step 17650 | content 177.5590 | style 0.0031 | tv 0.10933
# epoch 2/2 step 17700 | content 169.1862 | style 0.0028 | tv 0.10891
# epoch 2/2 step 17750 | content 167.8852 | style 0.0029 | tv 0.10866
# epoch 2/2 step 17800 | content 191.4274 | style 0.0032 | tv 0.10937
# epoch 2/2 step 17850 | content 169.5605 | style 0.0026 | tv 0.10939
# epoch 2/2 step 17900 | content 169.7906 | style 0.0024 | tv 0.10959
# epoch 2/2 step 17950 | content 154.8388 | style 0.0025 | tv 0.11051
# epoch 2/2 step 18000 | content 153.3145 | style 0.0027 | tv 0.10970
# epoch 2/2 step 18050 | content 168.9273 | style 0.0026 | tv 0.11027
# epoch 2/2 step 18100 | content 168.2124 | style 0.0032 | tv 0.10977
# epoch 2/2 step 18150 | content 146.3221 | style 0.0024 | tv 0.11120
# epoch 2/2 step 18200 | content 158.4065 | style 0.0027 | tv 0.10891
# epoch 2/2 step 18250 | content 162.9868 | style 0.0029 | tv 0.11074
# epoch 2/2 step 18300 | content 159.4585 | style 0.0024 | tv 0.10936
# epoch 2/2 step 18350 | content 150.6087 | style 0.0025 | tv 0.11134
# epoch 2/2 step 18400 | content 153.4796 | style 0.0028 | tv 0.11136
# epoch 2/2 step 18450 | content 149.0860 | style 0.0021 | tv 0.11045
# epoch 2/2 step 18500 | content 147.7693 | style 0.0023 | tv 0.11065
# epoch 2/2 step 18550 | content 164.8229 | style 0.0026 | tv 0.11227
# epoch 2/2 step 18600 | content 173.8208 | style 0.0024 | tv 0.11067
# epoch 2/2 step 18650 | content 165.6642 | style 0.0023 | tv 0.10840
# epoch 2/2 step 18700 | content 162.7815 | style 0.0032 | tv 0.10744
# epoch 2/2 step 18750 | content 160.4875 | style 0.0030 | tv 0.11164
# epoch 2/2 step 18800 | content 150.3674 | style 0.0030 | tv 0.11219
# epoch 2/2 step 18850 | content 163.2095 | style 0.0040 | tv 0.10995
# epoch 2/2 step 18900 | content 164.2951 | style 0.0028 | tv 0.11054
# epoch 2/2 step 18950 | content 154.2119 | style 0.0028 | tv 0.10999
# epoch 2/2 step 19000 | content 180.4603 | style 0.0025 | tv 0.10975
# epoch 2/2 step 19050 | content 154.7881 | style 0.0023 | tv 0.10975
# epoch 2/2 step 19100 | content 157.9618 | style 0.0021 | tv 0.11040
# epoch 2/2 step 19150 | content 158.5919 | style 0.0023 | tv 0.10843
# epoch 2/2 step 19200 | content 154.4361 | style 0.0023 | tv 0.11044
# epoch 2/2 step 19250 | content 153.1569 | style 0.0029 | tv 0.10860
# epoch 2/2 step 19300 | content 163.4630 | style 0.0020 | tv 0.10997
# epoch 2/2 step 19350 | content 154.4608 | style 0.0026 | tv 0.10957
# epoch 2/2 step 19400 | content 150.5877 | style 0.0025 | tv 0.11106
# epoch 2/2 step 19450 | content 160.7218 | style 0.0024 | tv 0.10970
# epoch 2/2 step 19500 | content 166.1695 | style 0.0020 | tv 0.10957
# epoch 2/2 step 19550 | content 160.9588 | style 0.0024 | tv 0.10907
# epoch 2/2 step 19600 | content 148.2185 | style 0.0023 | tv 0.10954
# epoch 2/2 step 19650 | content 163.3022 | style 0.0023 | tv 0.11121
# epoch 2/2 step 19700 | content 145.0634 | style 0.0025 | tv 0.11023
# epoch 2/2 step 19750 | content 156.9461 | style 0.0024 | tv 0.11197
# epoch 2/2 step 19800 | content 159.7460 | style 0.0024 | tv 0.10955
# epoch 2/2 step 19850 | content 160.3800 | style 0.0033 | tv 0.11085
# epoch 2/2 step 19900 | content 168.2836 | style 0.0020 | tv 0.11077
# epoch 2/2 step 19950 | content 151.6612 | style 0.0023 | tv 0.11000
# epoch 2/2 step 20000 | content 151.0150 | style 0.0024 | tv 0.11177
# epoch 2/2 step 20050 | content 142.4100 | style 0.0024 | tv 0.10974
# epoch 2/2 step 20100 | content 150.2446 | style 0.0025 | tv 0.11092
# epoch 2/2 step 20150 | content 149.5393 | style 0.0024 | tv 0.11184
# epoch 2/2 step 20200 | content 174.2773 | style 0.0025 | tv 0.10923
# epoch 2/2 step 20250 | content 150.1133 | style 0.0028 | tv 0.10906
# epoch 2/2 step 20300 | content 156.1188 | style 0.0027 | tv 0.11095
# epoch 2/2 step 20350 | content 159.1030 | style 0.0026 | tv 0.11020
# epoch 2/2 step 20400 | content 167.3540 | style 0.0025 | tv 0.10898
# epoch 2/2 step 20450 | content 162.2655 | style 0.0024 | tv 0.11004
# epoch 2/2 step 20500 | content 153.1011 | style 0.0024 | tv 0.11068
# epoch 2/2 step 20550 | content 159.0992 | style 0.0022 | tv 0.11096
# epoch 2/2 step 20600 | content 155.5361 | style 0.0029 | tv 0.11069
# epoch 2/2 step 20650 | content 150.7891 | style 0.0021 | tv 0.11017
# epoch 2/2 step 20700 | content 150.4575 | style 0.0023 | tv 0.10951
# epoch 2/2 step 20750 | content 156.4406 | style 0.0024 | tv 0.11079
# epoch 2/2 step 20800 | content 161.0318 | style 0.0028 | tv 0.11042
# epoch 2/2 step 20850 | content 155.0699 | style 0.0025 | tv 0.11111
# epoch 2/2 step 20900 | content 169.0980 | style 0.0023 | tv 0.11037
# epoch 2/2 step 20950 | content 153.3373 | style 0.0027 | tv 0.11036
# epoch 2/2 step 21000 | content 155.4169 | style 0.0024 | tv 0.11162
# epoch 2/2 step 21050 | content 161.2381 | style 0.0023 | tv 0.10996
# epoch 2/2 step 21100 | content 143.6465 | style 0.0023 | tv 0.11026
# epoch 2/2 step 21150 | content 150.5804 | style 0.0021 | tv 0.11060
# epoch 2/2 step 21200 | content 151.7143 | style 0.0023 | tv 0.10947
# epoch 2/2 step 21250 | content 159.2275 | style 0.0024 | tv 0.10868
# epoch 2/2 step 21300 | content 167.3525 | style 0.0020 | tv 0.10994
# epoch 2/2 step 21350 | content 152.1244 | style 0.0028 | tv 0.10880
# epoch 2/2 step 21400 | content 170.3645 | style 0.0028 | tv 0.11010
# epoch 2/2 step 21450 | content 144.8100 | style 0.0025 | tv 0.11147
# epoch 2/2 step 21500 | content 152.9978 | style 0.0025 | tv 0.10948
# epoch 2/2 step 21550 | content 160.1604 | style 0.0028 | tv 0.11033
# epoch 2/2 step 21600 | content 151.5320 | style 0.0022 | tv 0.11051
# epoch 2/2 step 21650 | content 157.1581 | style 0.0025 | tv 0.10974
# epoch 2/2 step 21700 | content 168.5462 | style 0.0030 | tv 0.10889
# epoch 2/2 step 21750 | content 161.5063 | style 0.0024 | tv 0.10934
# epoch 2/2 step 21800 | content 150.0522 | style 0.0021 | tv 0.11009
# epoch 2/2 step 21850 | content 160.3782 | style 0.0020 | tv 0.11011
# epoch 2/2 step 21900 | content 138.1203 | style 0.0026 | tv 0.11056
# epoch 2/2 step 21950 | content 156.5663 | style 0.0029 | tv 0.11095
# epoch 2/2 step 22000 | content 146.0211 | style 0.0028 | tv 0.11152
# epoch 2/2 step 22050 | content 170.9707 | style 0.0026 | tv 0.11049
# epoch 2/2 step 22100 | content 162.1462 | style 0.0023 | tv 0.10975
# epoch 2/2 step 24100 | content 159.5798 | style 0.0024 | tv 0.11151
# epoch 2/2 step 24150 | content 142.1012 | style 0.0025 | tv 0.10995
# epoch 2/2 step 24200 | content 138.1378 | style 0.0020 | tv 0.11055
# epoch 2/2 step 24250 | content 165.4884 | style 0.0022 | tv 0.11067
# epoch 2/2 step 24300 | content 155.9752 | style 0.0023 | tv 0.10853
# epoch 2/2 step 24350 | content 165.8014 | style 0.0027 | tv 0.10951
# epoch 2/2 step 24400 | content 151.8092 | style 0.0021 | tv 0.11069
# epoch 2/2 step 24450 | content 157.0078 | style 0.0024 | tv 0.11005
# epoch 2/2 step 24500 | content 147.6977 | style 0.0019 | tv 0.11134
# epoch 2/2 step 24550 | content 150.7733 | style 0.0027 | tv 0.11054
# epoch 2/2 step 24600 | content 137.5092 | style 0.0021 | tv 0.11068
# epoch 2/2 step 24650 | content 145.6921 | style 0.0023 | tv 0.10877
# epoch 2/2 step 24700 | content 163.1600 | style 0.0026 | tv 0.10914
# epoch 2/2 step 24750 | content 154.1617 | style 0.0025 | tv 0.10926
# epoch 2/2 step 24800 | content 148.2245 | style 0.0025 | tv 0.11068
# epoch 2/2 step 24850 | content 145.9615 | style 0.0021 | tv 0.11081
# epoch 2/2 step 24900 | content 145.0452 | style 0.0027 | tv 0.11063
# epoch 2/2 step 24950 | content 147.7985 | style 0.0023 | tv 0.10913
# Epoch 2 done in 4402.6s
# Saved model to kandinsky_transform_net.pth
# Saved stylized image to kandinsky_johnson_stylized.jpg

# %%
# Pablo Picasso Module
import os, math, time, random
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchvision import models, transforms
from PIL import Image
import numpy as np

# --------------------- Config ---------------------
CONTENT_IMAGE = "content test2.jpg"     # (your content path)
STYLE_IMAGE   = "Pablo_Picasso_style.jpeg"   # (your style path)
OUTPUT_IMAGE  = "Pablo_Picasso_johnson_stylized.jpg"
MODEL_PATH    = "Pablo_Picasso_transform_net.pth"

# Minimal "dataset" defaults to the single content image; point this to a folder for better training
CONTENT_DIR   = "content"       # folder of training content images (e.g., "./coco_subset"); "." uses the single content image
IMAGE_SIZE    = 512       # train/infer resolution (256/512/768). Higher => better quality, slower training
BATCH_SIZE    = 4
NUM_EPOCHS    = 2         # increase (e.g., 2–4) if you have a folder of content images
LEARNING_RATE = 1e-3
SEED          = 42
DEVICE        = "cuda" if torch.cuda.is_available() else "cpu"

# Perceptual loss weights (Johnson et al. typical ranges)
CONTENT_WEIGHT = 0.5
STYLE_WEIGHT   = 1e4      # try 5e3–1e4; if style is weak, raise this
TV_WEIGHT      = 1e-6

# VGG style/content layers (Johnson et al.: content=relu2_2; style=relu1_2, relu2_2, relu3_3, relu4_3)
LAYER_IDX = {
    "relu1_2": 3,
    "relu2_2": 8,
    "relu3_3": 15,
    "relu4_3": 22
}
STYLE_LAYERS   = ["relu1_2","relu2_2","relu3_3","relu4_3"]
CONTENT_LAYER  = "relu2_2"

random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# --------------------- Utils ---------------------
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

def load_image(path, size=None):
    img = Image.open(path).convert("RGB")
    if size is not None:
        img = img.resize((size, size), Image.BICUBIC)
    return img

def to_tensor(img):
    return transforms.ToTensor()(img)  # in [0,1]

def to_image(t: torch.Tensor) -> Image.Image:
    t = t.detach().clamp(0,1).cpu()
    return transforms.ToPILImage()(t.squeeze(0))

def normalize_batch(x):
    mean = IMAGENET_MEAN.to(x.device)
    std  = IMAGENET_STD.to(x.device)
    return (x - mean) / std

def gram_matrix(feat: torch.Tensor):
    # feat: [N,C,H,W] -> Gram per sample, normalized by C*H*W
    N, C, H, W = feat.size()
    f = feat.view(N, C, H*W)
    G = torch.bmm(f, f.transpose(1,2)) / (C*H*W)
    return G

def tv_loss(x):
    return (torch.mean(torch.abs(x[..., :, 1:] - x[..., :, :-1])) +
            torch.mean(torch.abs(x[..., 1:, :] - x[..., :-1, :])))

# --------------------- Transform Net (Johnson et al.) ---------------------
class ConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, stride):
        super().__init__()
        pad = kernel // 2
        self.pad = nn.ReflectionPad2d(pad)
        self.conv = nn.Conv2d(in_c, out_c, kernel, stride)
    def forward(self, x):
        return self.conv(self.pad(x))

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv1 = ConvLayer(channels, channels, 3, 1)
        self.in1   = nn.InstanceNorm2d(channels, affine=True)
        self.conv2 = ConvLayer(channels, channels, 3, 1)
        self.in2   = nn.InstanceNorm2d(channels, affine=True)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = self.in2(self.conv2(y))
        return x + y

class UpsampleConvLayer(nn.Module):
    def __init__(self, in_c, out_c, kernel, upsample=None):
        super().__init__()
        self.upsample = upsample
        self.pad = nn.ReflectionPad2d(kernel // 2)
        self.conv = nn.Conv2d(in_c, out_c, kernel, 1)
    def forward(self, x):
        if self.upsample:
            x = F.interpolate(x, scale_factor=self.upsample, mode="nearest")
        return self.conv(self.pad(x))

class TransformNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Encoder
        self.conv1 = ConvLayer(3, 32, 9, 1)
        self.in1   = nn.InstanceNorm2d(32, affine=True)
        self.conv2 = ConvLayer(32, 64, 3, 2)
        self.in2   = nn.InstanceNorm2d(64, affine=True)
        self.conv3 = ConvLayer(64, 128, 3, 2)
        self.in3   = nn.InstanceNorm2d(128, affine=True)
        # Residuals
        self.res   = nn.Sequential(*[ResidualBlock(128) for _ in range(5)])
        # Decoder
        self.up1   = UpsampleConvLayer(128, 64, 3, upsample=2)
        self.in4   = nn.InstanceNorm2d(64, affine=True)
        self.up2   = UpsampleConvLayer(64, 32, 3, upsample=2)
        self.in5   = nn.InstanceNorm2d(32, affine=True)
        self.conv4 = ConvLayer(32, 3, 9, 1)
    def forward(self, x):
        y = F.relu(self.in1(self.conv1(x)))
        y = F.relu(self.in2(self.conv2(y)))
        y = F.relu(self.in3(self.conv3(y)))
        y = self.res(y)
        y = F.relu(self.in4(self.up1(y)))
        y = F.relu(self.in5(self.up2(y)))
        y = torch.tanh(self.conv4(y))
        return (y + 1) / 2.0  # map from [-1,1] to [0,1]

# --------------------- VGG16 Loss Network ---------------------
class VGG16Features(nn.Module):
    def __init__(self, layers_idx):
        super().__init__()
        vgg = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_FEATURES).features.eval()
        for p in vgg.parameters(): p.requires_grad_(False)
        self.vgg = vgg
        self.layers_idx = layers_idx
    def forward(self, x):
        feats = {}
        for i, layer in enumerate(self.vgg):
            x = layer(x)
            for name, idx in self.layers_idx.items():
                if i == idx:
                    feats[name] = x
        return feats

# --------------------- Dataset ---------------------
class SingleOrFolderDataset(Dataset):
    def __init__(self, content_dir_or_file, image_size):
        super().__init__()
        p = Path(content_dir_or_file)
        if p.is_dir():
            self.paths = [str(pp) for pp in p.glob("*") if pp.suffix.lower() in [".jpg",".png",".jpeg",".bmp",".webp"]]
        else:
            self.paths = [str(p)]
        self.T = transforms.Compose([
            transforms.RandomResizedCrop(image_size, scale=(0.6, 1.0), ratio=(0.75, 1.33)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
        ])
    def __len__(self):
        return max(200, len(self.paths))  # repeat if just one file
    def __getitem__(self, idx):
        p = self.paths[idx % len(self.paths)]
        img = Image.open(p).convert("RGB")
        return self.T(img)

# --------------------- Prep ---------------------
assert Path(CONTENT_IMAGE).exists(), f"Not found: {CONTENT_IMAGE}"
assert Path(STYLE_IMAGE).exists(),   f"Not found: {STYLE_IMAGE}"

device = torch.device(DEVICE)
print("Using device:", device)

# Style targets (Gram matrices of VGG features for the style image)
style_img = load_image(STYLE_IMAGE, size=IMAGE_SIZE)
style_t   = to_tensor(style_img).unsqueeze(0).to(device)
vgg_loss_net = VGG16Features(LAYER_IDX).to(device)
with torch.no_grad():
    style_feats = vgg_loss_net(normalize_batch(style_t))
style_targets = {k: gram_matrix(v).detach() for k, v in style_feats.items() if k in STYLE_LAYERS}

# --------------------- Train Transform Net (per-style) ---------------------
transform_net = TransformNet().to(device)
optim = torch.optim.Adam(transform_net.parameters(), lr=LEARNING_RATE)

ds = SingleOrFolderDataset(CONTENT_DIR if Path(CONTENT_DIR).exists() else CONTENT_IMAGE, IMAGE_SIZE)
loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True, num_workers=2)

print(f"Training on {len(ds)} samples (repeating if needed). Epochs={NUM_EPOCHS}")
global_step = 0
for epoch in range(NUM_EPOCHS):
    t0 = time.time()
    for batch in loader:
        global_step += 1
        batch = batch.to(device)
        optim.zero_grad()

        y_hat = transform_net(batch)                # [0,1]
        y_hat_norm = normalize_batch(y_hat.clone()) # normalize for VGG

        # VGG features
        feats_y_hat = vgg_loss_net(y_hat_norm)
        feats_x     = vgg_loss_net(normalize_batch(batch))

        # Content loss (relu2_2)
        content_loss = F.mse_loss(feats_y_hat[CONTENT_LAYER], feats_x[CONTENT_LAYER])

        # Style loss (sum over layers)
        style_loss = 0.0
        for k in STYLE_LAYERS:
            gm_y = gram_matrix(feats_y_hat[k])
            gm_s = style_targets[k].expand_as(gm_y)
            style_loss += F.mse_loss(gm_y, gm_s)

        # TV regularization
        tv = tv_loss(y_hat)

        loss = CONTENT_WEIGHT * content_loss + STYLE_WEIGHT * style_loss + TV_WEIGHT * tv
        loss.backward()
        optim.step()

        if global_step % 50 == 0:
            print(f"epoch {epoch+1}/{NUM_EPOCHS} step {global_step:05d} | "
                  f"content {content_loss.item():.4f} | style {style_loss.item():.4f} | tv {tv.item():.5f}")

    print(f"Epoch {epoch+1} done in {time.time()-t0:.1f}s")

torch.save(transform_net.state_dict(), MODEL_PATH)
print(f"Saved model to {MODEL_PATH}")

# --------------------- Stylize your content image ---------------------
content_img = load_image(CONTENT_IMAGE, size=IMAGE_SIZE)
content_t   = to_tensor(content_img).unsqueeze(0).to(device)

transform_net.eval()
with torch.no_grad():
    out = transform_net(content_t)

to_image(out).save(OUTPUT_IMAGE)
print(f"Saved stylized image to {OUTPUT_IMAGE}")
# Out:
# Using device: cuda
# Training on 49981 samples (repeating if needed). Epochs=2
# epoch 1/2 step 00050 | content 68.7457 | style 0.0267 | tv 0.01154
# epoch 1/2 step 00100 | content 67.5726 | style 0.0153 | tv 0.01926
# epoch 1/2 step 00150 | content 95.6307 | style 0.0062 | tv 0.03187
# epoch 1/2 step 00200 | content 85.1662 | style 0.0056 | tv 0.03692
# epoch 1/2 step 00250 | content 96.1107 | style 0.0046 | tv 0.03700
# epoch 1/2 step 00300 | content 55.4893 | style 0.0040 | tv 0.03730
# epoch 1/2 step 00350 | content 67.7435 | style 0.0029 | tv 0.03518
# epoch 1/2 step 00400 | content 53.3389 | style 0.0035 | tv 0.03565
# epoch 1/2 step 00450 | content 78.9932 | style 0.0030 | tv 0.03894
# epoch 1/2 step 00500 | content 71.6288 | style 0.0029 | tv 0.03594
# epoch 1/2 step 00550 | content 65.4218 | style 0.0028 | tv 0.03793
# epoch 1/2 step 00600 | content 86.7335 | style 0.0032 | tv 0.03858
# epoch 1/2 step 00650 | content 85.6664 | style 0.0031 | tv 0.03875
# epoch 1/2 step 00700 | content 73.2846 | style 0.0033 | tv 0.03810
# epoch 1/2 step 00750 | content 51.6148 | style 0.0026 | tv 0.03842
# epoch 1/2 step 00800 | content 74.5857 | style 0.0019 | tv 0.03867
# epoch 1/2 step 00850 | content 55.8855 | style 0.0017 | tv 0.04104
# epoch 1/2 step 00900 | content 51.3864 | style 0.0015 | tv 0.03975
# epoch 1/2 step 00950 | content 53.2703 | style 0.0016 | tv 0.03975
# epoch 1/2 step 01000 | content 66.7997 | style 0.0018 | tv 0.04068
# epoch 1/2 step 01050 | content 39.4998 | style 0.0022 | tv 0.03949
# epoch 1/2 step 01100 | content 55.0376 | style 0.0019 | tv 0.04156
# epoch 1/2 step 01150 | content 61.8475 | style 0.0012 | tv 0.04025
# epoch 1/2 step 01200 | content 50.2168 | style 0.0014 | tv 0.04029
# epoch 1/2 step 01250 | content 70.3398 | style 0.0014 | tv 0.04254
# epoch 1/2 step 01300 | content 54.2710 | style 0.0013 | tv 0.04250
# epoch 1/2 step 01350 | content 63.2601 | style 0.0013 | tv 0.04270
# epoch 1/2 step 01400 | content 58.3180 | style 0.0014 | tv 0.04056
# epoch 1/2 step 01450 | content 57.5038 | style 0.0010 | tv 0.04204
# epoch 1/2 step 01500 | content 67.9059 | style 0.0014 | tv 0.04066
# epoch 2/2 step 15300 | content 30.9284 | style 0.0006 | tv 0.03794
# epoch 2/2 step 15350 | content 36.7735 | style 0.0005 | tv 0.03861
# epoch 2/2 step 15400 | content 32.1183 | style 0.0006 | tv 0.03821
# epoch 2/2 step 15450 | content 33.6070 | style 0.0004 | tv 0.03804
# epoch 2/2 step 15500 | content 41.3034 | style 0.0004 | tv 0.03766
# epoch 2/2 step 15550 | content 30.4098 | style 0.0005 | tv 0.03798
# epoch 2/2 step 15600 | content 22.4212 | style 0.0005 | tv 0.03816
# epoch 2/2 step 15650 | content 28.7922 | style 0.0005 | tv 0.03868
# epoch 2/2 step 15700 | content 26.8539 | style 0.0004 | tv 0.03655
# epoch 2/2 step 15750 | content 27.2714 | style 0.0006 | tv 0.03710
# epoch 2/2 step 15800 | content 23.2439 | style 0.0003 | tv 0.03769
# epoch 2/2 step 15850 | content 33.0067 | style 0.0005 | tv 0.03803
# epoch 2/2 step 15900 | content 32.8757 | style 0.0005 | tv 0.03705
# epoch 2/2 step 15950 | content 45.3541 | style 0.0004 | tv 0.03840
# epoch 2/2 step 16000 | content 35.6734 | style 0.0006 | tv 0.03857
# epoch 2/2 step 16050 | content 30.6474 | style 0.0004 | tv 0.03770
# epoch 2/2 step 16100 | content 33.1410 | style 0.0005 | tv 0.03781
# epoch 2/2 step 16150 | content 19.1538 | style 0.0005 | tv 0.03782
# epoch 2/2 step 16200 | content 29.3924 | style 0.0004 | tv 0.03835
# epoch 2/2 step 16250 | content 27.8712 | style 0.0004 | tv 0.03806
# epoch 2/2 step 16300 | content 30.7046 | style 0.0004 | tv 0.03801
# epoch 2/2 step 16350 | content 29.9733 | style 0.0004 | tv 0.03854
# epoch 2/2 step 16400 | content 26.7896 | style 0.0005 | tv 0.03724
# epoch 2/2 step 16450 | content 26.8165 | style 0.0005 | tv 0.03805
# epoch 2/2 step 16500 | content 43.7388 | style 0.0006 | tv 0.03860
# epoch 2/2 step 16550 | content 24.7379 | style 0.0004 | tv 0.03806
# epoch 2/2 step 16600 | content 27.0018 | style 0.0004 | tv 0.03812
# epoch 2/2 step 16650 | content 31.4888 | style 0.0005 | tv 0.03857
# epoch 2/2 step 16700 | content 33.8754 | style 0.0004 | tv 0.03862
# epoch 2/2 step 16750 | content 30.6357 | style 0.0004 | tv 0.03820
# epoch 2/2 step 16800 | content 31.8763 | style 0.0007 | tv 0.03768
# epoch 2/2 step 16850 | content 30.2325 | style 0.0004 | tv 0.03844
# epoch 2/2 step 16900 | content 33.6450 | style 0.0004 | tv 0.03803
# epoch 2/2 step 16950 | content 33.5706 | style 0.0004 | tv 0.03953
# epoch 2/2 step 17000 | content 24.0811 | style 0.0004 | tv 0.03747
# epoch 2/2 step 17050 | content 31.4629 | style 0.0005 | tv 0.03812
# epoch 2/2 step 17100 | content 23.9386 | style 0.0004 | tv 0.03816
# epoch 2/2 step 17150 | content 21.3062 | style 0.0005 | tv 0.03743
# epoch 2/2 step 17200 | content 26.0620 | style 0.0005 | tv 0.03735
# epoch 2/2 step 19200 | content 33.5663 | style 0.0005 | tv 0.03866
# epoch 2/2 step 19250 | content 26.1730 | style 0.0004 | tv 0.03762
# epoch 2/2 step 19300 | content 23.6725 | style 0.0004 | tv 0.03740
# epoch 2/2 step 19350 | content 23.6750 | style 0.0004 | tv 0.03740
# epoch 2/2 step 19400 | content 28.4325 | style 0.0005 | tv 0.03794
# epoch 2/2 step 19450 | content 30.7077 | style 0.0004 | tv 0.03811
# epoch 2/2 step 19500 | content 25.9928 | style 0.0005 | tv 0.03770
# epoch 2/2 step 19550 | content 19.8638 | style 0.0004 | tv 0.03756
# epoch 2/2 step 19600 | content 35.4254 | style 0.0003 | tv 0.03841
# epoch 2/2 step 19650 | content 24.2212 | style 0.0004 | tv 0.03767
# epoch 2/2 step 19700 | content 41.1236 | style 0.0005 | tv 0.03840
# epoch 2/2 step 19750 | content 21.2271 | style 0.0004 | tv 0.03777
# epoch 2/2 step 19800 | content 18.8102 | style 0.0004 | tv 0.03782
# epoch 2/2 step 19850 | content 35.5281 | style 0.0006 | tv 0.03861
# epoch 2/2 step 19900 | content 32.8619 | style 0.0004 | tv 0.03821
# epoch 2/2 step 19950 | content 29.5744 | style 0.0004 | tv 0.03787
# epoch 2/2 step 20000 | content 30.1895 | style 0.0005 | tv 0.03908
# epoch 2/2 step 20050 | content 37.2913 | style 0.0004 | tv 0.03807
# epoch 2/2 step 20100 | content 23.6053 | style 0.0004 | tv 0.03789
# epoch 2/2 step 20150 | content 36.3717 | style 0.0005 | tv 0.03870
# epoch 2/2 step 20200 | content 26.2529 | style 0.0005 | tv 0.03773
# epoch 2/2 step 20250 | content 33.7887 | style 0.0005 | tv 0.03901
# epoch 2/2 step 20300 | content 23.8799 | style 0.0005 | tv 0.03879
# epoch 2/2 step 20350 | content 31.3204 | style 0.0005 | tv 0.03843
# epoch 2/2 step 20400 | content 24.2135 | style 0.0004 | tv 0.03827
# epoch 2/2 step 20450 | content 25.5355 | style 0.0004 | tv 0.03856
# epoch 2/2 step 20500 | content 49.4047 | style 0.0004 | tv 0.03848
# epoch 2/2 step 20550 | content 29.4602 | style 0.0003 | tv 0.03820
# epoch 2/2 step 20600 | content 25.9156 | style 0.0005 | tv 0.03899
# epoch 2/2 step 20650 | content 21.5543 | style 0.0004 | tv 0.03882
# epoch 2/2 step 20700 | content 34.5101 | style 0.0004 | tv 0.03813
# epoch 2/2 step 20750 | content 23.0095 | style 0.0005 | tv 0.03733
# epoch 2/2 step 20800 | content 35.2648 | style 0.0005 | tv 0.03792
# epoch 2/2 step 20850 | content 25.7266 | style 0.0005 | tv 0.03839
# epoch 2/2 step 20900 | content 30.0410 | style 0.0005 | tv 0.03762
# epoch 2/2 step 20950 | content 17.4328 | style 0.0005 | tv 0.03899
# epoch 2/2 step 21000 | content 30.5367 | style 0.0006 | tv 0.03899
# epoch 2/2 step 21050 | content 20.2202 | style 0.0004 | tv 0.03851
# epoch 2/2 step 21100 | content 33.0333 | style 0.0004 | tv 0.03826
# epoch 2/2 step 21150 | content 25.8438 | style 0.0004 | tv 0.03878
# epoch 2/2 step 21200 | content 24.9614 | style 0.0004 | tv 0.03856
# epoch 2/2 step 21250 | content 37.5948 | style 0.0005 | tv 0.03820
# epoch 2/2 step 21300 | content 31.9050 | style 0.0004 | tv 0.03813
# epoch 2/2 step 21350 | content 28.8617 | style 0.0004 | tv 0.03844
# epoch 2/2 step 21400 | content 29.5882 | style 0.0005 | tv 0.03760
# epoch 2/2 step 21450 | content 32.3927 | style 0.0004 | tv 0.03796
# epoch 2/2 step 21500 | content 30.3360 | style 0.0003 | tv 0.03806
# epoch 2/2 step 21550 | content 30.4295 | style 0.0005 | tv 0.03742
# epoch 2/2 step 21600 | content 44.1872 | style 0.0004 | tv 0.03830
# epoch 2/2 step 21650 | content 27.8018 | style 0.0005 | tv 0.03842
# epoch 2/2 step 21700 | content 26.5361 | style 0.0006 | tv 0.03724
# epoch 2/2 step 21750 | content 42.1567 | style 0.0005 | tv 0.03830
# epoch 2/2 step 21800 | content 28.8922 | style 0.0003 | tv 0.03856
# epoch 2/2 step 21850 | content 25.1381 | style 0.0004 | tv 0.03866
# epoch 2/2 step 21900 | content 34.9103 | style 0.0004 | tv 0.03895
# epoch 2/2 step 21950 | content 45.5568 | style 0.0005 | tv 0.03882
# epoch 2/2 step 22000 | content 39.2189 | style 0.0004 | tv 0.03811
# epoch 2/2 step 22050 | content 42.3349 | style 0.0005 | tv 0.03809
# epoch 2/2 step 22100 | content 23.9336 | style 0.0004 | tv 0.03762
# epoch 2/2 step 22150 | content 31.0576 | style 0.0004 | tv 0.03820
# epoch 2/2 step 22200 | content 21.8900 | style 0.0004 | tv 0.03862
# epoch 2/2 step 22250 | content 25.1172 | style 0.0004 | tv 0.03886
# epoch 2/2 step 22300 | content 26.2353 | style 0.0003 | tv 0.03845
# epoch 2/2 step 22350 | content 37.7584 | style 0.0016 | tv 0.03603
# epoch 2/2 step 22400 | content 35.0025 | style 0.0006 | tv 0.03836
# epoch 2/2 step 22450 | content 34.9078 | style 0.0005 | tv 0.03789
# epoch 2/2 step 22500 | content 30.2881 | style 0.0004 | tv 0.03756
# epoch 2/2 step 22550 | content 32.3885 | style 0.0005 | tv 0.03747
# epoch 2/2 step 22600 | content 31.8368 | style 0.0005 | tv 0.03719
# epoch 2/2 step 22650 | content 46.2560 | style 0.0009 | tv 0.04001
# epoch 2/2 step 22700 | content 35.6170 | style 0.0006 | tv 0.03769
# epoch 2/2 step 22750 | content 27.3126 | style 0.0005 | tv 0.03820
# epoch 2/2 step 22800 | content 30.6479 | style 0.0005 | tv 0.03799
# epoch 2/2 step 22850 | content 31.6875 | style 0.0004 | tv 0.03745
# epoch 2/2 step 22900 | content 25.2588 | style 0.0004 | tv 0.03837
# epoch 2/2 step 22950 | content 28.7733 | style 0.0004 | tv 0.03884
# epoch 2/2 step 23000 | content 37.1883 | style 0.0004 | tv 0.03959
# epoch 2/2 step 23050 | content 37.9853 | style 0.0005 | tv 0.03907
# epoch 2/2 step 23100 | content 27.9893 | style 0.0004 | tv 0.03820
# epoch 2/2 step 23150 | content 24.8552 | style 0.0005 | tv 0.03800
# epoch 2/2 step 23200 | content 26.8036 | style 0.0004 | tv 0.03894
# epoch 2/2 step 23250 | content 22.3001 | style 0.0004 | tv 0.03857
# epoch 2/2 step 23300 | content 25.2707 | style 0.0004 | tv 0.03803
# epoch 2/2 step 23350 | content 27.1309 | style 0.0005 | tv 0.03879
# epoch 2/2 step 23400 | content 34.5363 | style 0.0006 | tv 0.03823
# epoch 2/2 step 23450 | content 33.5138 | style 0.0004 | tv 0.03851
# epoch 2/2 step 23500 | content 27.9819 | style 0.0003 | tv 0.03853
# epoch 2/2 step 23550 | content 18.1237 | style 0.0003 | tv 0.03782
# epoch 2/2 step 23600 | content 36.3799 | style 0.0005 | tv 0.03874
# epoch 2/2 step 23650 | content 30.9640 | style 0.0004 | tv 0.03908
# epoch 2/2 step 23700 | content 32.4855 | style 0.0004 | tv 0.03893
# epoch 2/2 step 23750 | content 44.4443 | style 0.0005 | tv 0.03839
# epoch 2/2 step 23800 | content 31.1171 | style 0.0006 | tv 0.03779
# epoch 2/2 step 23850 | content 39.3015 | style 0.0006 | tv 0.03852
# epoch 2/2 step 23900 | content 23.4939 | style 0.0005 | tv 0.03855
# epoch 2/2 step 23950 | content 32.1269 | style 0.0004 | tv 0.03812
# epoch 2/2 step 24000 | content 33.7423 | style 0.0004 | tv 0.03851
# epoch 2/2 step 24050 | content 31.4135 | style 0.0004 | tv 0.03768
# epoch 2/2 step 24100 | content 34.7950 | style 0.0004 | tv 0.03920
# epoch 2/2 step 24150 | content 25.5374 | style 0.0004 | tv 0.03889
# epoch 2/2 step 24200 | content 31.6348 | style 0.0004 | tv 0.03854
# epoch 2/2 step 24250 | content 21.4734 | style 0.0004 | tv 0.03822
# epoch 2/2 step 24300 | content 33.0936 | style 0.0005 | tv 0.03922
# epoch 2/2 step 24350 | content 24.0212 | style 0.0005 | tv 0.03810
# epoch 2/2 step 24400 | content 26.4503 | style 0.0004 | tv 0.03776
# epoch 2/2 step 24450 | content 28.9270 | style 0.0004 | tv 0.03905
# epoch 2/2 step 24500 | content 24.9551 | style 0.0004 | tv 0.03888
# epoch 2/2 step 24550 | content 39.9395 | style 0.0005 | tv 0.03909
# epoch 2/2 step 24600 | content 23.0835 | style 0.0004 | tv 0.03895
# epoch 2/2 step 24650 | content 22.8443 | style 0.0004 | tv 0.03902
# epoch 2/2 step 24700 | content 27.3572 | style 0.0004 | tv 0.03808
# epoch 2/2 step 24750 | content 26.8143 | style 0.0004 | tv 0.03876
# epoch 2/2 step 24800 | content 28.7599 | style 0.0004 | tv 0.03860
# epoch 2/2 step 24850 | content 27.1935 | style 0.0004 | tv 0.03934
# epoch 2/2 step 24900 | content 24.8825 | style 0.0004 | tv 0.03872
# epoch 2/2 step 24950 | content 25.8070 | style 0.0004 | tv 0.03792
# Epoch 2 done in 4408.9s
# Saved model to Pablo_Picasso_transform_net.pth
# Saved stylized image to Pablo_Picasso_johnson_stylized.jpg
